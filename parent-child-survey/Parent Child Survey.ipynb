# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_obey = pd.read_csv('data/obey.csv')

# %%
#Default plotting
plt.plot(df.columns[1:],df.iloc[0,1:],label=df.iloc[0,0])
plt.plot(df.columns[1:],df.iloc[1,1:],label=df.iloc[1,0])
plt.plot(df.columns[1:],df.iloc[2,1:],label=df.iloc[2,0])
plt.plot(df.columns[1:],df.iloc[3,1:],label=df.iloc[3,0])
plt.plot(df.columns[1:],df.iloc[4,1:],label=df.iloc[4,0])
plt.legend()
plt.xticks(rotation='vertical')
plt.show()

# %%
#Stacked line plot
plt.stackplot(df_obey.columns[1:]
              ,df_obey.iloc[[4,3,2,1,0],1:]
              ,labels=df_obey.iloc[[4,3,2,1,0],0])
plt.xticks(rotation='vertical')
plt.legend()

# %%
df_popular = pd.read_csv('data/popular.csv')
#Stacked line plot
plt.stackplot(df_popular.columns[1:]
              ,df_popular.iloc[[4,3,2,1,0],1:]
              ,labels=df_popular.iloc[[4,3,2,1,0],0])
plt.xticks(rotation='vertical')
plt.legend()

# %%
df_help = pd.read_csv('data/help_others.csv')
#Stacked line plot
plt.stackplot(df_help.columns[1:]
              ,df_help.iloc[[4,3,2,1,0],1:]
              ,labels=df_help.iloc[[4,3,2,1,0],0])
plt.xticks(rotation='vertical')
plt.legend()

# %%
df_think = pd.read_csv('data/think_for_self.csv')
#Stacked line plot
plt.stackplot(df_think.columns[1:]
              ,df_think.iloc[[4,3,2,1,0],1:]
              ,labels=df_think.iloc[[4,3,2,1,0],0])
plt.xticks(rotation='vertical')
plt.legend()

# %%
df_work = pd.read_csv('data/work_hard.csv')
#Stacked line plot
plt.stackplot(df_work.columns[1:]
              ,df_work.iloc[[4,3,2,1,0],1:]
              ,labels=df_work.iloc[[4,3,2,1,0],0])
plt.xticks(rotation='vertical')
plt.legend()
